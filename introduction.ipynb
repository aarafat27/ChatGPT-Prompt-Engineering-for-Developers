# %% [markdown]
# # Introduction

# %% [markdown]
# ![Screenshot%202023-05-04%20220237.png](attachment:Screenshot%202023-05-04%20220237.png)

# %% [markdown]
# # Principles of Prompting

# %% [markdown]
# ![Screenshot%202023-05-15%20141636.png](attachment:Screenshot%202023-05-15%20141636.png)

# %% [markdown]
# # First Principle

# %% [markdown]
# ![Screenshot%20%2862%29.png](attachment:Screenshot%20%2862%29.png)

# %% [markdown]
# # Second Principle

# %% [markdown]
# ![Screenshot%20%2866%29.png](attachment:Screenshot%20%2866%29.png)

# %% [markdown]
# # Model Limitations

# %% [markdown]
# ![Screenshot%20%2869%29.png](attachment:Screenshot%20%2869%29.png)

# %% [markdown]
# # Iterative Prompt Develoment

# %% [markdown]
# ![Screenshot%20%2872%29.png](attachment:Screenshot%20%2872%29.png)

# %% [markdown]
# ![Screenshot%20%2874%29.png](attachment:Screenshot%20%2874%29.png)

# %% [markdown]
# # Temperature of LLMs

# %% [markdown]
# ![Screenshot%20%2876%29.png](attachment:Screenshot%20%2876%29.png)

# %% [markdown]
# # OpenAI API

# %% [markdown]
# ![Screenshot%20%2878%29.png](attachment:Screenshot%20%2878%29.png)

# %% [markdown]
# # Types of Role

# %% [markdown]
# ![Screenshot%20%2883%29.png](attachment:Screenshot%20%2883%29.png)

# %% [markdown]
# ![Screenshot%202023-05-15%20155939.png](attachment:Screenshot%202023-05-15%20155939.png)

# %% [markdown]
# ![Screenshot%202023-05-15%20160201.png](attachment:Screenshot%202023-05-15%20160201.png)
